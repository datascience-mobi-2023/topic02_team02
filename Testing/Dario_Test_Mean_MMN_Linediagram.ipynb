# %%
import pandas as pd
import functions as fun
import data_cleanup as dc
import data_exploration as de
import matplotlib.pyplot as plt
import Documentation as bac
import seaborn as sns
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Downloads/Users/dario/MambaMentality/envs/dms/lib/python3.10/site-packages/pandas/core/nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/Downloads/Users/dario/MambaMentality/envs/dms/lib/python3.10/site-packages/pandas/core/nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
dna_sequence = "..."

# %%
rna_sequence = dna_sequence.replace("T", "U")

# %%
p53_codons = [rna_sequence[i:i+3] for i in range(0, len(rna_sequence), 3)]

# %%
mutated_p53 = de.generate_codon_variations(p53_codons)

# %%
aa = de.translate_codons_df(mutated_p53).astype(str)

# %%
de.select_smut(bac.gia_null_eto,aa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 de.select_smut(bac.gia_null_eto,aa)
#
# NameError: name 'bac' is not defined

# %%
heatmap_aa: pd.DataFrame = de.select_smut(bac.gia_null_eto,aa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 heatmap_aa: pd.DataFrame = de.select_smut(bac.gia_null_eto,aa)
#
# NameError: name 'bac' is not defined

# %%
heatmap_aa_T = heatmap_aa.transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 heatmap_aa_T = heatmap_aa.transpose()
#
# NameError: name 'heatmap_aa' is not defined

# %%
gia_null_eto_df: pd.DataFrame = (dc.df_transform(bac.gia_null_eto))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 gia_null_eto_df: pd.DataFrame = (dc.df_transform(bac.gia_null_eto))
#
# NameError: name 'bac' is not defined

# %%
kot_hum_df: pd.DataFrame = (dc.df_transform(bac.kot_hum))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 kot_hum_df: pd.DataFrame = (dc.df_transform(bac.kot_hum))
#
# NameError: name 'bac' is not defined

# %%
heatmap_aa_T.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 heatmap_aa_T.head(20)
#
# NameError: name 'heatmap_aa_T' is not defined

# %%
fun.multiple_hmap(heatmap_aa_T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 fun.multiple_hmap(heatmap_aa_T)
#
# NameError: name 'heatmap_aa_T' is not defined

# %%
plt.figure(figsize=(50, 8))
sns.set(font_scale=2)
sns.heatmap(heatmap_aa_T, cmap='seismic')
plt.title('DMS Scores for Mutations')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 plt.figure(figsize=(50, 8))
#       2 sns.set(font_scale=2)
# ----> 3 sns.heatmap(heatmap_aa_T, cmap='seismic')
#       4 plt.title('DMS Scores for Mutations')
#       5 plt.show()
#
# NameError: name 'heatmap_aa_T' is not defined

# %%
print(gia_null_eto_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(gia_null_eto_df)
#
# NameError: name 'gia_null_eto_df' is not defined

# %%
print(heatmap_aa_T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(heatmap_aa_T)
#
# NameError: name 'heatmap_aa_T' is not defined

# %%
heatmap_aa_T.index = gia_null_eto_df.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 heatmap_aa_T.index = gia_null_eto_df.index
#
# NameError: name 'gia_null_eto_df' is not defined

# %%
heatmap_aa_T.columns = gia_null_eto_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 heatmap_aa_T.columns = gia_null_eto_df.columns
#
# NameError: name 'gia_null_eto_df' is not defined

# %%
fun.hmap(gia_null_eto_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 fun.hmap(gia_null_eto_df)
#
# NameError: name 'gia_null_eto_df' is not defined

# %%
bac.gia_null_eto_auf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 bac.gia_null_eto_auf
#
# NameError: name 'bac' is not defined

# %%
fun.hmap(bac.gia_null_eto_auf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 fun.hmap(bac.gia_null_eto_auf)
#
# NameError: name 'bac' is not defined

# %%
kot_hum_df_mean: pd.DataFrame = fun.df_mean(kot_hum_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 kot_hum_df_mean: pd.DataFrame = fun.df_mean(kot_hum_df)
#
# NameError: name 'kot_hum_df' is not defined

# %%
def hmap(df):
    plt.figure(figsize=(50, 8))
    sns.set(font_scale=2)
    sns.heatmap(df, cmap='seismic')
    plt.title('DMS Scores for Mutations')
    plt.show()

# %%
hmap(heatmap_aa_T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 hmap(heatmap_aa_T)
#
# NameError: name 'heatmap_aa_T' is not defined

# %%
kot_hum_df.name = 'kot_hum_df'
heatmap_aa_T.name = 'heatmap_aa_T'
gia_null_eto_df.name = 'gia_null_eto'
dataframes=[gia_null_eto_df, heatmap_aa_T, kot_hum_df]
# figsize kann verändert werden je nach Präferenz
plt.figure(figsize=(40, 6))
# for-loop der jeden Eintrag in der Liste "Dataframes" durchgeht
for df in dataframes:
    # Werte für x-Achse aus 'position_mut' als int extrahiert
    x = df.columns.get_level_values('position_mut').astype(int)
    # Werte für y-Achse aus erster Zeile von df als float extrahiert
    y = df.iloc[0].values.astype(float)
    label = df.name
    plt.plot(x, y, label=label, marker='o')
plt.xlabel('position')
plt.ylabel('DMS_score')
plt.title('Mean DMS_scores of different datasets throughout each position of tp53')
#WARUM ZUR VERDAMMTEN HÖLLE MACHT ER NUR 102 BIS 292 ICH VERSTEHE ES NICHT BITTE BEENDE ES
plt.xticks(np.arange(0, 393+1, 10))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 kot_hum_df.name = 'kot_hum_df'
#       2 heatmap_aa_T.name = 'heatmap_aa_T'
#       3 gia_null_eto_df.name = 'gia_null_eto'
#
# NameError: name 'kot_hum_df' is not defined

# %%
#plt.plot(x[::10], y[::10], label=label, marker='o')

# %%
fun.df_mean(bac.gia_null_eto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 fun.df_mean(bac.gia_null_eto)
#
# NameError: name 'bac' is not defined

# %%
gia_null_eto_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 gia_null_eto_df
#
# NameError: name 'gia_null_eto_df' is not defined

# %%
fun.df_mean(heatmap_aa_T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 fun.df_mean(heatmap_aa_T)
#
# NameError: name 'heatmap_aa_T' is not defined
